# %%
#======================================================================
#
#     This routine solves an infinite horizon growth model 
#     with dynamic programming and sparse grids
#
#     The model is described in Scheidegger & Bilionis (2017)
#     https://papers.ssrn.com/sol3/papers.cfm?abstract_id=2927400
#
#     external libraries needed:
#     - IPOPT (https://projects.coin-or.org/Ipopt)
#     - PYIPOPT (https://github.com/xuy/pyipopt)
#     - TASMANIAN (http://tasmanian.ornl.gov/)
#
#     Simon Scheidegger, 11/16 ; 07/17
#======================================================================

import nonlinear_solver_initial as solver     #solves opt. problems for terminal VF
import nonlinear_solver_iterate as solviter   #solves opt. problems during VFI
from parameters import *                      #parameters of model
import interpolation as interpol              #interface to sparse grid library/terminal VF
import interpolation_iter as interpol_iter    #interface to sparse grid library/iteration
import postprocessing as post                 #computes the L2 and Linfinity error of the model

import TasmanianSG                            #sparse grid library
import numpy as np


#======================================================================
# Start with Value Function Iteration

# terminal value function : "ss", no uncertainty --> ss values of c,l,k
valnew=TasmanianSG.TasmanianSparseGrid()
lvalnew=[valnew, valnew, valnew, valnew, valnew]
if (numstart==0):
    for g in range(5):
        iG = g
        print("Evaluating grid for state", iG)
        lvalnew[iG]=interpol.sparse_grid(n_agents, iDepth, iG)
        lvalnew[iG].plotResponse2D()
        points = lvalnew[iG].getPoints()
        print(points)

    
# value function during iteration --> take ss values of c,l,k and 
else:
    print("Set numstart to 0 PLEEEEASE")
    
valold=TasmanianSG.TasmanianSparseGrid()
lvalold=[valold, valold, valold, valold, valold]

for i in range(numstart, numits):
    print("Iteration number", i) 
    for g in range(5):
        iG = g
        print("Evaluating grid for state", iG)
        lvalnew[iG]=TasmanianSG.TasmanianSparseGrid()
        print("reaching T's error")
        lvalnew[iG]=interpol_iter.sparse_grid_iter(n_agents, iDepth, lvalold, iG)
        points = lvalnew[iG].getPoints()

        lvalold[iG]=TasmanianSG.TasmanianSparseGrid()
        lvalold[iG]=lvalnew[iG]


#======================================================================
print( "===============================================================")
print( " " )
print( " Computation of a growth model of dimension ", n_agents ," finished after ", numits, " steps")
print( " " )
print( "===============================================================")
#======================================================================

# compute errors   
avg_err=post.ls_error(n_agents, numstart, numits, No_samples)

#======================================================================
print( "===============================================================")
print( " ")
print( " Errors are computed -- see errors.txt")
print( " ")
print( "===============================================================")
#======================================================================
# Out:
# ('Evaluating grid for state', 0)
# ('Refinement level', 0)
# ('Refinement level', 1)
# ('Refinement level', 2)
# [[1.6   1.6  ]
#  [1.6   0.2  ]
#  [1.6   3.   ]
#  [1.6   0.9  ]
#  [1.6   2.3  ]
#  [1.6   0.55 ]
#  [1.6   1.25 ]
#  [1.6   1.95 ]
#  [1.6   2.65 ]
#  [1.6   0.375]
#  [1.6   0.725]
#  [1.6   1.075]
#  [1.6   1.425]
#  [1.6   1.775]
#  [1.6   2.125]
#  [1.6   2.475]
#  [1.6   2.825]
#  [0.2   1.6  ]
#  [0.2   0.2  ]
#  [0.2   3.   ]
#  [0.2   0.9  ]
#  [0.2   2.3  ]
#  [0.2   0.55 ]
#  [0.2   1.25 ]
#  [0.2   1.95 ]
#  [0.2   2.65 ]
#  [3.    1.6  ]
#  [3.    0.2  ]
#  [3.    3.   ]
#  [3.    0.9  ]
#  [3.    2.3  ]
#  [3.    0.55 ]
#  [3.    1.25 ]
#  [3.    1.95 ]
#  [3.    2.65 ]
#  [0.9   1.6  ]
#  [0.9   0.2  ]
#  [0.9   3.   ]
#  [0.9   0.9  ]
#  [0.9   2.3  ]
#  [2.3   1.6  ]
#  [2.3   0.2  ]
#  [2.3   3.   ]
#  [2.3   0.9  ]
#  [2.3   2.3  ]
#  [0.55  1.6  ]
#  [0.55  0.2  ]
#  [0.55  3.   ]
#  [1.25  1.6  ]
#  [1.25  0.2  ]
#  [1.25  3.   ]
#  [1.95  1.6  ]
#  [1.95  0.2  ]
#  [2.65  1.6  ]
#  [2.65  0.2  ]]
# ('Evaluating grid for state', 1)
# ('Refinement level', 0)
# ('Refinement level', 1)
# ('Refinement level', 2)
# [[1.6   1.6  ]
#  [1.6   0.2  ]
#  [1.6   3.   ]
#  [1.6   0.9  ]
#  [1.6   2.3  ]
#  [1.6   0.55 ]
#  [1.6   1.25 ]
#  [1.6   1.95 ]
#  [1.6   2.65 ]
#  [1.6   0.375]
#  [1.6   0.725]
#  [1.6   1.075]
#  [1.6   1.425]
#  [1.6   1.775]
#  [1.6   2.125]
#  [1.6   2.475]
#  [1.6   2.825]
#  [0.2   1.6  ]
#  [0.2   0.2  ]
#  [0.2   3.   ]
#  [0.2   0.9  ]
#  [0.2   2.3  ]
#  [0.2   0.55 ]
#  [0.2   1.25 ]
#  [0.2   1.95 ]
#  [0.2   2.65 ]
#  [3.    1.6  ]
#  [3.    0.2  ]
#  [3.    3.   ]
#  [3.    0.9  ]
#  [3.    2.3  ]
#  [3.    0.55 ]
#  [3.    1.25 ]
#  [3.    1.95 ]
#  [3.    2.65 ]
#  [0.9   1.6  ]
#  [0.9   0.2  ]
#  [0.9   3.   ]
#  [0.9   0.9  ]
#  [0.9   2.3  ]
#  [2.3   1.6  ]
#  [2.3   0.2  ]
#  [2.3   3.   ]
#  [2.3   0.9  ]
#  [2.3   2.3  ]
#  [0.55  1.6  ]
#  [0.55  0.2  ]
#  [0.55  3.   ]
#  [1.25  1.6  ]
#  [1.25  0.2  ]
#  [1.25  3.   ]
#  [1.95  1.6  ]
#  [1.95  0.2  ]
#  [2.65  1.6  ]
#  [2.65  0.2  ]]
# ('Evaluating grid for state', 2)
# ('Refinement level', 0)
# ('Refinement level', 1)
# ('Refinement level', 2)
# [[1.6   1.6  ]
#  [1.6   0.2  ]
#  [1.6   3.   ]
#  [1.6   0.9  ]
#  [1.6   2.3  ]
#  [1.6   0.55 ]
#  [1.6   1.25 ]
#  [1.6   1.95 ]
#  [1.6   2.65 ]
#  [1.6   0.375]
#  [1.6   0.725]
#  [1.6   1.075]
#  [1.6   1.425]
#  [1.6   1.775]
#  [1.6   2.125]
#  [1.6   2.475]
#  [1.6   2.825]
#  [0.2   1.6  ]
#  [0.2   0.2  ]
#  [0.2   3.   ]
#  [0.2   0.9  ]
#  [0.2   2.3  ]
#  [0.2   0.55 ]
#  [0.2   1.25 ]
#  [0.2   1.95 ]
#  [0.2   2.65 ]
#  [3.    1.6  ]
#  [3.    0.2  ]
#  [3.    3.   ]
#  [3.    0.9  ]
#  [3.    2.3  ]
#  [3.    0.55 ]
#  [3.    1.25 ]
#  [3.    1.95 ]
#  [3.    2.65 ]
#  [0.9   1.6  ]
#  [0.9   0.2  ]
#  [0.9   3.   ]
#  [0.9   0.9  ]
#  [0.9   2.3  ]
#  [2.3   1.6  ]
#  [2.3   0.2  ]
#  [2.3   3.   ]
#  [2.3   0.9  ]
#  [2.3   2.3  ]
#  [0.55  1.6  ]
#  [0.55  0.2  ]
#  [0.55  3.   ]
#  [1.25  1.6  ]
#  [1.25  0.2  ]
#  [1.25  3.   ]
#  [1.95  1.6  ]
#  [1.95  0.2  ]
#  [2.65  1.6  ]
#  [2.65  0.2  ]]
# ('Evaluating grid for state', 3)
# ('Refinement level', 0)
# ('Refinement level', 1)
# ('Refinement level', 2)
# [[1.6   1.6  ]
#  [1.6   0.2  ]
#  [1.6   3.   ]
#  [1.6   0.9  ]
#  [1.6   2.3  ]
#  [1.6   0.55 ]
#  [1.6   1.25 ]
#  [1.6   1.95 ]
#  [1.6   2.65 ]
#  [1.6   0.375]
#  [1.6   0.725]
#  [1.6   1.075]
#  [1.6   1.425]
#  [1.6   1.775]
#  [1.6   2.125]
#  [1.6   2.475]
#  [1.6   2.825]
#  [0.2   1.6  ]
#  [0.2   0.2  ]
#  [0.2   3.   ]
#  [0.2   0.9  ]
#  [0.2   2.3  ]
#  [0.2   0.55 ]
#  [0.2   1.25 ]
#  [0.2   1.95 ]
#  [0.2   2.65 ]
#  [3.    1.6  ]
#  [3.    0.2  ]
#  [3.    3.   ]
#  [3.    0.9  ]
#  [3.    2.3  ]
#  [3.    0.55 ]
#  [3.    1.25 ]
#  [3.    1.95 ]
#  [3.    2.65 ]
#  [0.9   1.6  ]
#  [0.9   0.2  ]
#  [0.9   3.   ]
#  [0.9   0.9  ]
#  [0.9   2.3  ]
#  [2.3   1.6  ]
#  [2.3   0.2  ]
#  [2.3   3.   ]
#  [2.3   0.9  ]
#  [2.3   2.3  ]
#  [0.55  1.6  ]
#  [0.55  0.2  ]
#  [0.55  3.   ]
#  [1.25  1.6  ]
#  [1.25  0.2  ]
#  [1.25  3.   ]
#  [1.95  1.6  ]
#  [1.95  0.2  ]
#  [2.65  1.6  ]
#  [2.65  0.2  ]]
# ('Evaluating grid for state', 4)
# ('Refinement level', 0)
# ('Refinement level', 1)
# ('Refinement level', 2)
# ERROR: found problem with lfX
# ERROR: lfX should have lenth 2 instead it has length 0
# [[1.6   1.6  ]
#  [1.6   0.2  ]
#  [1.6   3.   ]
#  [1.6   0.9  ]
#  [1.6   2.3  ]
#  [1.6   0.55 ]
#  [1.6   1.25 ]
#  [1.6   1.95 ]
#  [1.6   2.65 ]
#  [1.6   0.375]
#  [1.6   0.725]
#  [1.6   1.075]
#  [1.6   1.425]
#  [1.6   1.775]
#  [1.6   2.125]
#  [1.6   2.475]
#  [1.6   2.825]
#  [0.2   1.6  ]
#  [0.2   0.2  ]
#  [0.2   3.   ]
#  [0.2   0.9  ]
#  [0.2   2.3  ]
#  [0.2   0.55 ]
#  [0.2   1.25 ]
#  [0.2   1.95 ]
#  [0.2   2.65 ]
#  [3.    1.6  ]
#  [3.    0.2  ]
#  [3.    3.   ]
#  [3.    0.9  ]
#  [3.    2.3  ]
#  [3.    0.55 ]
#  [3.    1.25 ]
#  [3.    1.95 ]
#  [3.    2.65 ]
#  [0.9   1.6  ]
#  [0.9   0.2  ]
#  [0.9   3.   ]
#  [0.9   0.9  ]
#  [0.9   2.3  ]
#  [2.3   1.6  ]
#  [2.3   0.2  ]
#  [2.3   3.   ]
#  [2.3   0.9  ]
#  [2.3   2.3  ]
#  [0.55  1.6  ]
#  [0.55  0.2  ]
#  [0.55  3.   ]
#  [1.25  1.6  ]
#  [1.25  0.2  ]
#  [1.25  3.   ]
#  [1.95  1.6  ]
#  [1.95  0.2  ]
#  [2.65  1.6  ]
#  [2.65  0.2  ]]
# ('Iteration number', 0)
# ('Evaluating grid for state', 0)
# reaching T's error
# 5
# succes 1
# succes 2
# [<TasmanianSG.TasmanianSparseGrid instance at 0x7f5955b03a70>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f5955b03a70>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f5955b03a70>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f5955b03a70>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f5955b03a70>]
# ('lvalold0', <TasmanianSG.TasmanianSparseGrid instance at 0x7f5955b03a70>)
# [5009.79794716 4995.51602739]
# ---------------------------------------------------------------------------
# TasmanianInputError                       Traceback (most recent call last)
# /home/rccguest6110/OSE2019_JS/day1/SparseGridCode/growth_model/adaptive_stochastic/nonlinear_solver_iterate.pyc in eval_f(X)
#      74
#      75     def eval_f(X):
# ---> 76         return EV_F_ITER(X, k_init, n_agents, lvalold, phi_i)
#      77
#      78     def eval_grad_f(x):
#
# /home/rccguest6110/OSE2019_JS/day1/SparseGridCode/growth_model/adaptive_stochastic/ipopt_wrapper.py in EV_F_ITER(X, k_init, n_agents, lvalold, phi_i)
#      57         pi*lvalold[1].evaluate(knext) +
#      58         pi*lvalold[2].evaluate(knext) +
# ---> 59         pi*lvalold[3].evaluate(knext) +
#      60         pi*lvalold[4].evaluate(knext))
#      61
#
# /home/rccguest6110/OSE2019_JS/day1/SparseGridCode/growth_model/adaptive_stochastic/TasmanianSG.pyc in evaluate(self, lfX)
#     878         iNumX = len(lfX)
#     879         if (iNumX != self.getNumDimensions()):
# --> 880             raise TasmanianInputError("lfX", "ERROR: lfX should have lenth {0:1d} instead it has length {1:1d}".format(iNumX, self.getNumDimensions()))
#     881         pX = (c_double*iNumX)()
#     882         for iI in range(iNumX):
#
# TasmanianInputError:
# ERROR: found problem with lfX
# ERROR: lfX should have lenth 2 instead it has length 0
# succes 3
# succes 1
# succes 2
# [<TasmanianSG.TasmanianSparseGrid instance at 0x7f5955b03a70>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f5955b03a70>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f5955b03a70>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f5955b03a70>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f5955b03a70>]
# ('lvalold0', <TasmanianSG.TasmanianSparseGrid instance at 0x7f5955b03a70>)
# [5009.79794716 4994.15102739]
# ---------------------------------------------------------------------------
# TasmanianInputError                       Traceback (most recent call last)
# /home/rccguest6110/OSE2019_JS/day1/SparseGridCode/growth_model/adaptive_stochastic/nonlinear_solver_iterate.pyc in eval_f(X)
#      74
#      75     def eval_f(X):
# ---> 76         return EV_F_ITER(X, k_init, n_agents, lvalold, phi_i)
#      77
#      78     def eval_grad_f(x):
#
# /home/rccguest6110/OSE2019_JS/day1/SparseGridCode/growth_model/adaptive_stochastic/ipopt_wrapper.py in EV_F_ITER(X, k_init, n_agents, lvalold, phi_i)
#      57         pi*lvalold[1].evaluate(knext) +
#      58         pi*lvalold[2].evaluate(knext) +
# ---> 59         pi*lvalold[3].evaluate(knext) +
#      60         pi*lvalold[4].evaluate(knext))
#      61
#
# /home/rccguest6110/OSE2019_JS/day1/SparseGridCode/growth_model/adaptive_stochastic/TasmanianSG.pyc in evaluate(self, lfX)
#     878         iNumX = len(lfX)
#     879         if (iNumX != self.getNumDimensions()):
# --> 880             raise TasmanianInputError("lfX", "ERROR: lfX should have lenth {0:1d} instead it has length {1:1d}".format(iNumX, self.getNumDimensions()))
#     881         pX = (c_double*iNumX)()
#     882         for iI in range(iNumX):
#
# TasmanianInputError:
# ERROR: found problem with lfX
# ERROR: lfX should have lenth 2 instead it has length 0
# succes 3
# succes 1
# succes 2
# [<TasmanianSG.TasmanianSparseGrid instance at 0x7f5955b03a70>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f5955b03a70>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f5955b03a70>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f5955b03a70>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f5955b03a70>]
# ('lvalold0', <TasmanianSG.TasmanianSparseGrid instance at 0x7f5955b03a70>)
# [5009.79794716 4996.88102739]
# ---------------------------------------------------------------------------
# TasmanianInputError                       Traceback (most recent call last)
# /home/rccguest6110/OSE2019_JS/day1/SparseGridCode/growth_model/adaptive_stochastic/nonlinear_solver_iterate.pyc in eval_f(X)
#      74
#      75     def eval_f(X):
# ---> 76         return EV_F_ITER(X, k_init, n_agents, lvalold, phi_i)
#      77
#      78     def eval_grad_f(x):
#
# /home/rccguest6110/OSE2019_JS/day1/SparseGridCode/growth_model/adaptive_stochastic/ipopt_wrapper.py in EV_F_ITER(X, k_init, n_agents, lvalold, phi_i)
#      57         pi*lvalold[1].evaluate(knext) +
#      58         pi*lvalold[2].evaluate(knext) +
# ---> 59         pi*lvalold[3].evaluate(knext) +
#      60         pi*lvalold[4].evaluate(knext))
#      61
#
# /home/rccguest6110/OSE2019_JS/day1/SparseGridCode/growth_model/adaptive_stochastic/TasmanianSG.pyc in evaluate(self, lfX)
#     878         iNumX = len(lfX)
#     879         if (iNumX != self.getNumDimensions()):
# --> 880             raise TasmanianInputError("lfX", "ERROR: lfX should have lenth {0:1d} instead it has length {1:1d}".format(iNumX, self.getNumDimensions()))
#     881         pX = (c_double*iNumX)()
#     882         for iI in range(iNumX):
#
# TasmanianInputError:
# ERROR: found problem with lfX
# ERROR: lfX should have lenth 2 instead it has length 0
# succes 3
# succes 1
# succes 2
# [<TasmanianSG.TasmanianSparseGrid instance at 0x7f5955b03a70>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f5955b03a70>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f5955b03a70>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f5955b03a70>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f5955b03a70>]
# ('lvalold0', <TasmanianSG.TasmanianSparseGrid instance at 0x7f5955b03a70>)
# [5008.43294716 4995.51602739]
# ---------------------------------------------------------------------------
# TasmanianInputError                       Traceback (most recent call last)
# /home/rccguest6110/OSE2019_JS/day1/SparseGridCode/growth_model/adaptive_stochastic/nonlinear_solver_iterate.pyc in eval_f(X)
#      74
#      75     def eval_f(X):
# ---> 76         return EV_F_ITER(X, k_init, n_agents, lvalold, phi_i)
#      77
#      78     def eval_grad_f(x):
#
# /home/rccguest6110/OSE2019_JS/day1/SparseGridCode/growth_model/adaptive_stochastic/ipopt_wrapper.py in EV_F_ITER(X, k_init, n_agents, lvalold, phi_i)
#      57         pi*lvalold[1].evaluate(knext) +
#      58         pi*lvalold[2].evaluate(knext) +
# ---> 59         pi*lvalold[3].evaluate(knext) +
#      60         pi*lvalold[4].evaluate(knext))
#      61
#
# /home/rccguest6110/OSE2019_JS/day1/SparseGridCode/growth_model/adaptive_stochastic/TasmanianSG.pyc in evaluate(self, lfX)
#     878         iNumX = len(lfX)
#     879         if (iNumX != self.getNumDimensions()):
# --> 880             raise TasmanianInputError("lfX", "ERROR: lfX should have lenth {0:1d} instead it has length {1:1d}".format(iNumX, self.getNumDimensions()))
#     881         pX = (c_double*iNumX)()
#     882         for iI in range(iNumX):
#
# TasmanianInputError:
# ERROR: found problem with lfX
# ERROR: lfX should have lenth 2 instead it has length 0
# succes 3
# succes 1
# succes 2
# [<TasmanianSG.TasmanianSparseGrid instance at 0x7f5955b03a70>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f5955b03a70>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f5955b03a70>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f5955b03a70>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f5955b03a70>]
# ('lvalold0', <TasmanianSG.TasmanianSparseGrid instance at 0x7f5955b03a70>)
# [5011.16294716 4995.51602739]
# ---------------------------------------------------------------------------
# TasmanianInputError                       Traceback (most recent call last)
# /home/rccguest6110/OSE2019_JS/day1/SparseGridCode/growth_model/adaptive_stochastic/nonlinear_solver_iterate.pyc in eval_f(X)
#      74
#      75     def eval_f(X):
# ---> 76         return EV_F_ITER(X, k_init, n_agents, lvalold, phi_i)
#      77
#      78     def eval_grad_f(x):
#
# /home/rccguest6110/OSE2019_JS/day1/SparseGridCode/growth_model/adaptive_stochastic/ipopt_wrapper.py in EV_F_ITER(X, k_init, n_agents, lvalold, phi_i)
#      57         pi*lvalold[1].evaluate(knext) +
#      58         pi*lvalold[2].evaluate(knext) +
# ---> 59         pi*lvalold[3].evaluate(knext) +
#      60         pi*lvalold[4].evaluate(knext))
#      61
#
# /home/rccguest6110/OSE2019_JS/day1/SparseGridCode/growth_model/adaptive_stochastic/TasmanianSG.pyc in evaluate(self, lfX)
#     878         iNumX = len(lfX)
#     879         if (iNumX != self.getNumDimensions()):
# --> 880             raise TasmanianInputError("lfX", "ERROR: lfX should have lenth {0:1d} instead it has length {1:1d}".format(iNumX, self.getNumDimensions()))
#     881         pX = (c_double*iNumX)()
#     882         for iI in range(iNumX):
#
# TasmanianInputError:
# ERROR: found problem with lfX
# ERROR: lfX should have lenth 2 instead it has length 0
# succes 3
# 5
# ('Refinement level', 0)
# 0
# ('Refinement level', 1)
# 0
# ('Refinement level', 2)
# ('Evaluating grid for state', 1)
# reaching T's error
# 5
# succes 1
# succes 2
# [<TasmanianSG.TasmanianSparseGrid instance at 0x7f594dc51830>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f5955b03a70>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f5955b03a70>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f5955b03a70>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f5955b03a70>]
# ('lvalold0', <TasmanianSG.TasmanianSparseGrid instance at 0x7f594dc51830>)
# [5009.79794716 4995.51602739]
# ---------------------------------------------------------------------------
# TasmanianInputError                       Traceback (most recent call last)
# /home/rccguest6110/OSE2019_JS/day1/SparseGridCode/growth_model/adaptive_stochastic/nonlinear_solver_iterate.pyc in eval_f(X)
#      74
#      75     def eval_f(X):
# ---> 76         return EV_F_ITER(X, k_init, n_agents, lvalold, phi_i)
#      77
#      78     def eval_grad_f(x):
#
# /home/rccguest6110/OSE2019_JS/day1/SparseGridCode/growth_model/adaptive_stochastic/ipopt_wrapper.py in EV_F_ITER(X, k_init, n_agents, lvalold, phi_i)
#      57         pi*lvalold[1].evaluate(knext) +
#      58         pi*lvalold[2].evaluate(knext) +
# ---> 59         pi*lvalold[3].evaluate(knext) +
#      60         pi*lvalold[4].evaluate(knext))
#      61
#
# /home/rccguest6110/OSE2019_JS/day1/SparseGridCode/growth_model/adaptive_stochastic/TasmanianSG.pyc in evaluate(self, lfX)
#     878         iNumX = len(lfX)
#     879         if (iNumX != self.getNumDimensions()):
# --> 880             raise TasmanianInputError("lfX", "ERROR: lfX should have lenth {0:1d} instead it has length {1:1d}".format(iNumX, self.getNumDimensions()))
#     881         pX = (c_double*iNumX)()
#     882         for iI in range(iNumX):
#
# TasmanianInputError:
# ERROR: found problem with lfX
# ERROR: lfX should have lenth 2 instead it has length 0
# succes 3
# succes 1
# succes 2
# [<TasmanianSG.TasmanianSparseGrid instance at 0x7f594dc51830>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f5955b03a70>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f5955b03a70>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f5955b03a70>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f5955b03a70>]
# ('lvalold0', <TasmanianSG.TasmanianSparseGrid instance at 0x7f594dc51830>)
# [5009.79794716 4994.15102739]
# ---------------------------------------------------------------------------
# TasmanianInputError                       Traceback (most recent call last)
# /home/rccguest6110/OSE2019_JS/day1/SparseGridCode/growth_model/adaptive_stochastic/nonlinear_solver_iterate.pyc in eval_f(X)
#      74
#      75     def eval_f(X):
# ---> 76         return EV_F_ITER(X, k_init, n_agents, lvalold, phi_i)
#      77
#      78     def eval_grad_f(x):
#
# /home/rccguest6110/OSE2019_JS/day1/SparseGridCode/growth_model/adaptive_stochastic/ipopt_wrapper.py in EV_F_ITER(X, k_init, n_agents, lvalold, phi_i)
#      57         pi*lvalold[1].evaluate(knext) +
#      58         pi*lvalold[2].evaluate(knext) +
# ---> 59         pi*lvalold[3].evaluate(knext) +
#      60         pi*lvalold[4].evaluate(knext))
#      61
#
# /home/rccguest6110/OSE2019_JS/day1/SparseGridCode/growth_model/adaptive_stochastic/TasmanianSG.pyc in evaluate(self, lfX)
#     878         iNumX = len(lfX)
#     879         if (iNumX != self.getNumDimensions()):
# --> 880             raise TasmanianInputError("lfX", "ERROR: lfX should have lenth {0:1d} instead it has length {1:1d}".format(iNumX, self.getNumDimensions()))
#     881         pX = (c_double*iNumX)()
#     882         for iI in range(iNumX):
#
# TasmanianInputError:
# ERROR: found problem with lfX
# ERROR: lfX should have lenth 2 instead it has length 0
# succes 3
# succes 1
# succes 2
# [<TasmanianSG.TasmanianSparseGrid instance at 0x7f594dc51830>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f5955b03a70>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f5955b03a70>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f5955b03a70>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f5955b03a70>]
# ('lvalold0', <TasmanianSG.TasmanianSparseGrid instance at 0x7f594dc51830>)
# [5009.79794716 4996.88102739]
# ---------------------------------------------------------------------------
# TasmanianInputError                       Traceback (most recent call last)
# /home/rccguest6110/OSE2019_JS/day1/SparseGridCode/growth_model/adaptive_stochastic/nonlinear_solver_iterate.pyc in eval_f(X)
#      74
#      75     def eval_f(X):
# ---> 76         return EV_F_ITER(X, k_init, n_agents, lvalold, phi_i)
#      77
#      78     def eval_grad_f(x):
#
# /home/rccguest6110/OSE2019_JS/day1/SparseGridCode/growth_model/adaptive_stochastic/ipopt_wrapper.py in EV_F_ITER(X, k_init, n_agents, lvalold, phi_i)
#      57         pi*lvalold[1].evaluate(knext) +
#      58         pi*lvalold[2].evaluate(knext) +
# ---> 59         pi*lvalold[3].evaluate(knext) +
#      60         pi*lvalold[4].evaluate(knext))
#      61
#
# /home/rccguest6110/OSE2019_JS/day1/SparseGridCode/growth_model/adaptive_stochastic/TasmanianSG.pyc in evaluate(self, lfX)
#     878         iNumX = len(lfX)
#     879         if (iNumX != self.getNumDimensions()):
# --> 880             raise TasmanianInputError("lfX", "ERROR: lfX should have lenth {0:1d} instead it has length {1:1d}".format(iNumX, self.getNumDimensions()))
#     881         pX = (c_double*iNumX)()
#     882         for iI in range(iNumX):
#
# TasmanianInputError:
# ERROR: found problem with lfX
# ERROR: lfX should have lenth 2 instead it has length 0
# succes 3
# succes 1
# succes 2
# [<TasmanianSG.TasmanianSparseGrid instance at 0x7f594dc51830>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f5955b03a70>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f5955b03a70>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f5955b03a70>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f5955b03a70>]
# ('lvalold0', <TasmanianSG.TasmanianSparseGrid instance at 0x7f594dc51830>)
# [5008.43294716 4995.51602739]
# ---------------------------------------------------------------------------
# TasmanianInputError                       Traceback (most recent call last)
# /home/rccguest6110/OSE2019_JS/day1/SparseGridCode/growth_model/adaptive_stochastic/nonlinear_solver_iterate.pyc in eval_f(X)
#      74
#      75     def eval_f(X):
# ---> 76         return EV_F_ITER(X, k_init, n_agents, lvalold, phi_i)
#      77
#      78     def eval_grad_f(x):
#
# /home/rccguest6110/OSE2019_JS/day1/SparseGridCode/growth_model/adaptive_stochastic/ipopt_wrapper.py in EV_F_ITER(X, k_init, n_agents, lvalold, phi_i)
#      57         pi*lvalold[1].evaluate(knext) +
#      58         pi*lvalold[2].evaluate(knext) +
# ---> 59         pi*lvalold[3].evaluate(knext) +
#      60         pi*lvalold[4].evaluate(knext))
#      61
#
# /home/rccguest6110/OSE2019_JS/day1/SparseGridCode/growth_model/adaptive_stochastic/TasmanianSG.pyc in evaluate(self, lfX)
#     878         iNumX = len(lfX)
#     879         if (iNumX != self.getNumDimensions()):
# --> 880             raise TasmanianInputError("lfX", "ERROR: lfX should have lenth {0:1d} instead it has length {1:1d}".format(iNumX, self.getNumDimensions()))
#     881         pX = (c_double*iNumX)()
#     882         for iI in range(iNumX):
#
# TasmanianInputError:
# ERROR: found problem with lfX
# ERROR: lfX should have lenth 2 instead it has length 0
# succes 3
# succes 1
# succes 2
# [<TasmanianSG.TasmanianSparseGrid instance at 0x7f594dc51830>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f5955b03a70>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f5955b03a70>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f5955b03a70>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f5955b03a70>]
# ('lvalold0', <TasmanianSG.TasmanianSparseGrid instance at 0x7f594dc51830>)
# [5011.16294716 4995.51602739]
# ---------------------------------------------------------------------------
# TasmanianInputError                       Traceback (most recent call last)
# /home/rccguest6110/OSE2019_JS/day1/SparseGridCode/growth_model/adaptive_stochastic/nonlinear_solver_iterate.pyc in eval_f(X)
#      74
#      75     def eval_f(X):
# ---> 76         return EV_F_ITER(X, k_init, n_agents, lvalold, phi_i)
#      77
#      78     def eval_grad_f(x):
#
# /home/rccguest6110/OSE2019_JS/day1/SparseGridCode/growth_model/adaptive_stochastic/ipopt_wrapper.py in EV_F_ITER(X, k_init, n_agents, lvalold, phi_i)
#      57         pi*lvalold[1].evaluate(knext) +
#      58         pi*lvalold[2].evaluate(knext) +
# ---> 59         pi*lvalold[3].evaluate(knext) +
#      60         pi*lvalold[4].evaluate(knext))
#      61
#
# /home/rccguest6110/OSE2019_JS/day1/SparseGridCode/growth_model/adaptive_stochastic/TasmanianSG.pyc in evaluate(self, lfX)
#     878         iNumX = len(lfX)
#     879         if (iNumX != self.getNumDimensions()):
# --> 880             raise TasmanianInputError("lfX", "ERROR: lfX should have lenth {0:1d} instead it has length {1:1d}".format(iNumX, self.getNumDimensions()))
#     881         pX = (c_double*iNumX)()
#     882         for iI in range(iNumX):
#
# TasmanianInputError:
# ERROR: found problem with lfX
# ERROR: lfX should have lenth 2 instead it has length 0
# succes 3
# 5
# ('Refinement level', 0)
# 0
# ('Refinement level', 1)
# 0
# ('Refinement level', 2)
# ('Evaluating grid for state', 2)
# reaching T's error
# 5
# succes 1
# succes 2
# [<TasmanianSG.TasmanianSparseGrid instance at 0x7f594dc51830>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f594dbb77a0>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f5955b03a70>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f5955b03a70>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f5955b03a70>]
# ('lvalold0', <TasmanianSG.TasmanianSparseGrid instance at 0x7f594dc51830>)
# [5009.79794716 4995.51602739]
# ---------------------------------------------------------------------------
# TasmanianInputError                       Traceback (most recent call last)
# /home/rccguest6110/OSE2019_JS/day1/SparseGridCode/growth_model/adaptive_stochastic/nonlinear_solver_iterate.pyc in eval_f(X)
#      74
#      75     def eval_f(X):
# ---> 76         return EV_F_ITER(X, k_init, n_agents, lvalold, phi_i)
#      77
#      78     def eval_grad_f(x):
#
# /home/rccguest6110/OSE2019_JS/day1/SparseGridCode/growth_model/adaptive_stochastic/ipopt_wrapper.py in EV_F_ITER(X, k_init, n_agents, lvalold, phi_i)
#      57         pi*lvalold[1].evaluate(knext) +
#      58         pi*lvalold[2].evaluate(knext) +
# ---> 59         pi*lvalold[3].evaluate(knext) +
#      60         pi*lvalold[4].evaluate(knext))
#      61
#
# /home/rccguest6110/OSE2019_JS/day1/SparseGridCode/growth_model/adaptive_stochastic/TasmanianSG.pyc in evaluate(self, lfX)
#     878         iNumX = len(lfX)
#     879         if (iNumX != self.getNumDimensions()):
# --> 880             raise TasmanianInputError("lfX", "ERROR: lfX should have lenth {0:1d} instead it has length {1:1d}".format(iNumX, self.getNumDimensions()))
#     881         pX = (c_double*iNumX)()
#     882         for iI in range(iNumX):
#
# TasmanianInputError:
# ERROR: found problem with lfX
# ERROR: lfX should have lenth 2 instead it has length 0
# succes 3
# succes 1
# succes 2
# [<TasmanianSG.TasmanianSparseGrid instance at 0x7f594dc51830>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f594dbb77a0>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f5955b03a70>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f5955b03a70>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f5955b03a70>]
# ('lvalold0', <TasmanianSG.TasmanianSparseGrid instance at 0x7f594dc51830>)
# [5009.79794716 4994.15102739]
# ---------------------------------------------------------------------------
# TasmanianInputError                       Traceback (most recent call last)
# /home/rccguest6110/OSE2019_JS/day1/SparseGridCode/growth_model/adaptive_stochastic/nonlinear_solver_iterate.pyc in eval_f(X)
#      74
#      75     def eval_f(X):
# ---> 76         return EV_F_ITER(X, k_init, n_agents, lvalold, phi_i)
#      77
#      78     def eval_grad_f(x):
#
# /home/rccguest6110/OSE2019_JS/day1/SparseGridCode/growth_model/adaptive_stochastic/ipopt_wrapper.py in EV_F_ITER(X, k_init, n_agents, lvalold, phi_i)
#      57         pi*lvalold[1].evaluate(knext) +
#      58         pi*lvalold[2].evaluate(knext) +
# ---> 59         pi*lvalold[3].evaluate(knext) +
#      60         pi*lvalold[4].evaluate(knext))
#      61
#
# /home/rccguest6110/OSE2019_JS/day1/SparseGridCode/growth_model/adaptive_stochastic/TasmanianSG.pyc in evaluate(self, lfX)
#     878         iNumX = len(lfX)
#     879         if (iNumX != self.getNumDimensions()):
# --> 880             raise TasmanianInputError("lfX", "ERROR: lfX should have lenth {0:1d} instead it has length {1:1d}".format(iNumX, self.getNumDimensions()))
#     881         pX = (c_double*iNumX)()
#     882         for iI in range(iNumX):
#
# TasmanianInputError:
# ERROR: found problem with lfX
# ERROR: lfX should have lenth 2 instead it has length 0
# succes 3
# succes 1
# succes 2
# [<TasmanianSG.TasmanianSparseGrid instance at 0x7f594dc51830>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f594dbb77a0>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f5955b03a70>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f5955b03a70>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f5955b03a70>]
# ('lvalold0', <TasmanianSG.TasmanianSparseGrid instance at 0x7f594dc51830>)
# [5009.79794716 4996.88102739]
# ---------------------------------------------------------------------------
# TasmanianInputError                       Traceback (most recent call last)
# /home/rccguest6110/OSE2019_JS/day1/SparseGridCode/growth_model/adaptive_stochastic/nonlinear_solver_iterate.pyc in eval_f(X)
#      74
#      75     def eval_f(X):
# ---> 76         return EV_F_ITER(X, k_init, n_agents, lvalold, phi_i)
#      77
#      78     def eval_grad_f(x):
#
# /home/rccguest6110/OSE2019_JS/day1/SparseGridCode/growth_model/adaptive_stochastic/ipopt_wrapper.py in EV_F_ITER(X, k_init, n_agents, lvalold, phi_i)
#      57         pi*lvalold[1].evaluate(knext) +
#      58         pi*lvalold[2].evaluate(knext) +
# ---> 59         pi*lvalold[3].evaluate(knext) +
#      60         pi*lvalold[4].evaluate(knext))
#      61
#
# /home/rccguest6110/OSE2019_JS/day1/SparseGridCode/growth_model/adaptive_stochastic/TasmanianSG.pyc in evaluate(self, lfX)
#     878         iNumX = len(lfX)
#     879         if (iNumX != self.getNumDimensions()):
# --> 880             raise TasmanianInputError("lfX", "ERROR: lfX should have lenth {0:1d} instead it has length {1:1d}".format(iNumX, self.getNumDimensions()))
#     881         pX = (c_double*iNumX)()
#     882         for iI in range(iNumX):
#
# TasmanianInputError:
# ERROR: found problem with lfX
# ERROR: lfX should have lenth 2 instead it has length 0
# succes 3
# succes 1
# succes 2
# [<TasmanianSG.TasmanianSparseGrid instance at 0x7f594dc51830>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f594dbb77a0>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f5955b03a70>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f5955b03a70>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f5955b03a70>]
# ('lvalold0', <TasmanianSG.TasmanianSparseGrid instance at 0x7f594dc51830>)
# [5008.43294716 4995.51602739]
# ---------------------------------------------------------------------------
# TasmanianInputError                       Traceback (most recent call last)
# /home/rccguest6110/OSE2019_JS/day1/SparseGridCode/growth_model/adaptive_stochastic/nonlinear_solver_iterate.pyc in eval_f(X)
#      74
#      75     def eval_f(X):
# ---> 76         return EV_F_ITER(X, k_init, n_agents, lvalold, phi_i)
#      77
#      78     def eval_grad_f(x):
#
# /home/rccguest6110/OSE2019_JS/day1/SparseGridCode/growth_model/adaptive_stochastic/ipopt_wrapper.py in EV_F_ITER(X, k_init, n_agents, lvalold, phi_i)
#      57         pi*lvalold[1].evaluate(knext) +
#      58         pi*lvalold[2].evaluate(knext) +
# ---> 59         pi*lvalold[3].evaluate(knext) +
#      60         pi*lvalold[4].evaluate(knext))
#      61
#
# /home/rccguest6110/OSE2019_JS/day1/SparseGridCode/growth_model/adaptive_stochastic/TasmanianSG.pyc in evaluate(self, lfX)
#     878         iNumX = len(lfX)
#     879         if (iNumX != self.getNumDimensions()):
# --> 880             raise TasmanianInputError("lfX", "ERROR: lfX should have lenth {0:1d} instead it has length {1:1d}".format(iNumX, self.getNumDimensions()))
#     881         pX = (c_double*iNumX)()
#     882         for iI in range(iNumX):
#
# TasmanianInputError:
# ERROR: found problem with lfX
# ERROR: lfX should have lenth 2 instead it has length 0
# succes 3
# succes 1
# succes 2
# [<TasmanianSG.TasmanianSparseGrid instance at 0x7f594dc51830>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f594dbb77a0>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f5955b03a70>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f5955b03a70>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f5955b03a70>]
# ('lvalold0', <TasmanianSG.TasmanianSparseGrid instance at 0x7f594dc51830>)
# [5011.16294716 4995.51602739]
# ---------------------------------------------------------------------------
# TasmanianInputError                       Traceback (most recent call last)
# /home/rccguest6110/OSE2019_JS/day1/SparseGridCode/growth_model/adaptive_stochastic/nonlinear_solver_iterate.pyc in eval_f(X)
#      74
#      75     def eval_f(X):
# ---> 76         return EV_F_ITER(X, k_init, n_agents, lvalold, phi_i)
#      77
#      78     def eval_grad_f(x):
#
# /home/rccguest6110/OSE2019_JS/day1/SparseGridCode/growth_model/adaptive_stochastic/ipopt_wrapper.py in EV_F_ITER(X, k_init, n_agents, lvalold, phi_i)
#      57         pi*lvalold[1].evaluate(knext) +
#      58         pi*lvalold[2].evaluate(knext) +
# ---> 59         pi*lvalold[3].evaluate(knext) +
#      60         pi*lvalold[4].evaluate(knext))
#      61
#
# /home/rccguest6110/OSE2019_JS/day1/SparseGridCode/growth_model/adaptive_stochastic/TasmanianSG.pyc in evaluate(self, lfX)
#     878         iNumX = len(lfX)
#     879         if (iNumX != self.getNumDimensions()):
# --> 880             raise TasmanianInputError("lfX", "ERROR: lfX should have lenth {0:1d} instead it has length {1:1d}".format(iNumX, self.getNumDimensions()))
#     881         pX = (c_double*iNumX)()
#     882         for iI in range(iNumX):
#
# TasmanianInputError:
# ERROR: found problem with lfX
# ERROR: lfX should have lenth 2 instead it has length 0
# succes 3
# 5
# ('Refinement level', 0)
# 0
# ('Refinement level', 1)
# 0
# ('Refinement level', 2)
# ('Evaluating grid for state', 3)
# reaching T's error
# 5
# succes 1
# succes 2
# [<TasmanianSG.TasmanianSparseGrid instance at 0x7f594dc51830>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f594dbb77a0>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f594db6f9e0>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f5955b03a70>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f5955b03a70>]
# ('lvalold0', <TasmanianSG.TasmanianSparseGrid instance at 0x7f594dc51830>)
# [5009.79794716 4995.51602739]
# ---------------------------------------------------------------------------
# TasmanianInputError                       Traceback (most recent call last)
# /home/rccguest6110/OSE2019_JS/day1/SparseGridCode/growth_model/adaptive_stochastic/nonlinear_solver_iterate.pyc in eval_f(X)
#      74
#      75     def eval_f(X):
# ---> 76         return EV_F_ITER(X, k_init, n_agents, lvalold, phi_i)
#      77
#      78     def eval_grad_f(x):
#
# /home/rccguest6110/OSE2019_JS/day1/SparseGridCode/growth_model/adaptive_stochastic/ipopt_wrapper.py in EV_F_ITER(X, k_init, n_agents, lvalold, phi_i)
#      57         pi*lvalold[1].evaluate(knext) +
#      58         pi*lvalold[2].evaluate(knext) +
# ---> 59         pi*lvalold[3].evaluate(knext) +
#      60         pi*lvalold[4].evaluate(knext))
#      61
#
# /home/rccguest6110/OSE2019_JS/day1/SparseGridCode/growth_model/adaptive_stochastic/TasmanianSG.pyc in evaluate(self, lfX)
#     878         iNumX = len(lfX)
#     879         if (iNumX != self.getNumDimensions()):
# --> 880             raise TasmanianInputError("lfX", "ERROR: lfX should have lenth {0:1d} instead it has length {1:1d}".format(iNumX, self.getNumDimensions()))
#     881         pX = (c_double*iNumX)()
#     882         for iI in range(iNumX):
#
# TasmanianInputError:
# ERROR: found problem with lfX
# ERROR: lfX should have lenth 2 instead it has length 0
# succes 3
# succes 1
# succes 2
# [<TasmanianSG.TasmanianSparseGrid instance at 0x7f594dc51830>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f594dbb77a0>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f594db6f9e0>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f5955b03a70>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f5955b03a70>]
# ('lvalold0', <TasmanianSG.TasmanianSparseGrid instance at 0x7f594dc51830>)
# [5009.79794716 4994.15102739]
# ---------------------------------------------------------------------------
# TasmanianInputError                       Traceback (most recent call last)
# /home/rccguest6110/OSE2019_JS/day1/SparseGridCode/growth_model/adaptive_stochastic/nonlinear_solver_iterate.pyc in eval_f(X)
#      74
#      75     def eval_f(X):
# ---> 76         return EV_F_ITER(X, k_init, n_agents, lvalold, phi_i)
#      77
#      78     def eval_grad_f(x):
#
# /home/rccguest6110/OSE2019_JS/day1/SparseGridCode/growth_model/adaptive_stochastic/ipopt_wrapper.py in EV_F_ITER(X, k_init, n_agents, lvalold, phi_i)
#      57         pi*lvalold[1].evaluate(knext) +
#      58         pi*lvalold[2].evaluate(knext) +
# ---> 59         pi*lvalold[3].evaluate(knext) +
#      60         pi*lvalold[4].evaluate(knext))
#      61
#
# /home/rccguest6110/OSE2019_JS/day1/SparseGridCode/growth_model/adaptive_stochastic/TasmanianSG.pyc in evaluate(self, lfX)
#     878         iNumX = len(lfX)
#     879         if (iNumX != self.getNumDimensions()):
# --> 880             raise TasmanianInputError("lfX", "ERROR: lfX should have lenth {0:1d} instead it has length {1:1d}".format(iNumX, self.getNumDimensions()))
#     881         pX = (c_double*iNumX)()
#     882         for iI in range(iNumX):
#
# TasmanianInputError:
# succes 3
# succes 1
# succes 2
# [<TasmanianSG.TasmanianSparseGrid instance at 0x7f594dc51830>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f594dbb77a0>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f594db6f9e0>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f5955b03a70>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f5955b03a70>]
# ('lvalold0', <TasmanianSG.TasmanianSparseGrid instance at 0x7f594dc51830>)
# [5009.79794716 4996.88102739]
# ERROR: found problem with lfX
# ERROR: lfX should have lenth 2 instead it has length 0
# ---------------------------------------------------------------------------
# TasmanianInputError                       Traceback (most recent call last)
# /home/rccguest6110/OSE2019_JS/day1/SparseGridCode/growth_model/adaptive_stochastic/nonlinear_solver_iterate.pyc in eval_f(X)
#      74
#      75     def eval_f(X):
# ---> 76         return EV_F_ITER(X, k_init, n_agents, lvalold, phi_i)
#      77
#      78     def eval_grad_f(x):
#
# /home/rccguest6110/OSE2019_JS/day1/SparseGridCode/growth_model/adaptive_stochastic/ipopt_wrapper.py in EV_F_ITER(X, k_init, n_agents, lvalold, phi_i)
#      57         pi*lvalold[1].evaluate(knext) +
#      58         pi*lvalold[2].evaluate(knext) +
# ---> 59         pi*lvalold[3].evaluate(knext) +
#      60         pi*lvalold[4].evaluate(knext))
#      61
#
# /home/rccguest6110/OSE2019_JS/day1/SparseGridCode/growth_model/adaptive_stochastic/TasmanianSG.pyc in evaluate(self, lfX)
#     878         iNumX = len(lfX)
#     879         if (iNumX != self.getNumDimensions()):
# --> 880             raise TasmanianInputError("lfX", "ERROR: lfX should have lenth {0:1d} instead it has length {1:1d}".format(iNumX, self.getNumDimensions()))
#     881         pX = (c_double*iNumX)()
#     882         for iI in range(iNumX):
#
# TasmanianInputError:
# ERROR: found problem with lfX
# ERROR: lfX should have lenth 2 instead it has length 0
# succes 3
# succes 1
# succes 2
# [<TasmanianSG.TasmanianSparseGrid instance at 0x7f594dc51830>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f594dbb77a0>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f594db6f9e0>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f5955b03a70>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f5955b03a70>]
# ('lvalold0', <TasmanianSG.TasmanianSparseGrid instance at 0x7f594dc51830>)
# [5008.43294716 4995.51602739]
# ---------------------------------------------------------------------------
# TasmanianInputError                       Traceback (most recent call last)
# /home/rccguest6110/OSE2019_JS/day1/SparseGridCode/growth_model/adaptive_stochastic/nonlinear_solver_iterate.pyc in eval_f(X)
#      74
#      75     def eval_f(X):
# ---> 76         return EV_F_ITER(X, k_init, n_agents, lvalold, phi_i)
#      77
#      78     def eval_grad_f(x):
#
# /home/rccguest6110/OSE2019_JS/day1/SparseGridCode/growth_model/adaptive_stochastic/ipopt_wrapper.py in EV_F_ITER(X, k_init, n_agents, lvalold, phi_i)
#      57         pi*lvalold[1].evaluate(knext) +
#      58         pi*lvalold[2].evaluate(knext) +
# ---> 59         pi*lvalold[3].evaluate(knext) +
#      60         pi*lvalold[4].evaluate(knext))
#      61
#
# /home/rccguest6110/OSE2019_JS/day1/SparseGridCode/growth_model/adaptive_stochastic/TasmanianSG.pyc in evaluate(self, lfX)
#     878         iNumX = len(lfX)
#     879         if (iNumX != self.getNumDimensions()):
# --> 880             raise TasmanianInputError("lfX", "ERROR: lfX should have lenth {0:1d} instead it has length {1:1d}".format(iNumX, self.getNumDimensions()))
#     881         pX = (c_double*iNumX)()
#     882         for iI in range(iNumX):
#
# TasmanianInputError:
# ERROR: found problem with lfX
# ERROR: lfX should have lenth 2 instead it has length 0
# succes 3
# succes 1
# succes 2
# [<TasmanianSG.TasmanianSparseGrid instance at 0x7f594dc51830>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f594dbb77a0>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f594db6f9e0>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f5955b03a70>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f5955b03a70>]
# ('lvalold0', <TasmanianSG.TasmanianSparseGrid instance at 0x7f594dc51830>)
# [5011.16294716 4995.51602739]
# ---------------------------------------------------------------------------
# TasmanianInputError                       Traceback (most recent call last)
# /home/rccguest6110/OSE2019_JS/day1/SparseGridCode/growth_model/adaptive_stochastic/nonlinear_solver_iterate.pyc in eval_f(X)
#      74
#      75     def eval_f(X):
# ---> 76         return EV_F_ITER(X, k_init, n_agents, lvalold, phi_i)
#      77
#      78     def eval_grad_f(x):
#
# /home/rccguest6110/OSE2019_JS/day1/SparseGridCode/growth_model/adaptive_stochastic/ipopt_wrapper.py in EV_F_ITER(X, k_init, n_agents, lvalold, phi_i)
#      57         pi*lvalold[1].evaluate(knext) +
#      58         pi*lvalold[2].evaluate(knext) +
# ---> 59         pi*lvalold[3].evaluate(knext) +
#      60         pi*lvalold[4].evaluate(knext))
#      61
#
# /home/rccguest6110/OSE2019_JS/day1/SparseGridCode/growth_model/adaptive_stochastic/TasmanianSG.pyc in evaluate(self, lfX)
#     878         iNumX = len(lfX)
#     879         if (iNumX != self.getNumDimensions()):
# --> 880             raise TasmanianInputError("lfX", "ERROR: lfX should have lenth {0:1d} instead it has length {1:1d}".format(iNumX, self.getNumDimensions()))
#     881         pX = (c_double*iNumX)()
#     882         for iI in range(iNumX):
#
# TasmanianInputError:
# succes 3
# 5
# ('Refinement level', 0)
# 0
# ('Refinement level', 1)
# 0
# ('Refinement level', 2)
# ('Evaluating grid for state', 4)
# reaching T's error
# 5
# succes 1
# succes 2
# [<TasmanianSG.TasmanianSparseGrid instance at 0x7f594dc51830>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f594dbb77a0>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f594db6f9e0>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f594db1ef80>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f5955b03a70>]
# ('lvalold0', <TasmanianSG.TasmanianSparseGrid instance at 0x7f594dc51830>)
# ERROR: found problem with lfX
# ERROR: lfX should have lenth 2 instead it has length 0
# [5009.79794716 4995.51602739]
# ---------------------------------------------------------------------------
# TasmanianInputError                       Traceback (most recent call last)
# /home/rccguest6110/OSE2019_JS/day1/SparseGridCode/growth_model/adaptive_stochastic/nonlinear_solver_iterate.pyc in eval_f(X)
#      74
#      75     def eval_f(X):
# ---> 76         return EV_F_ITER(X, k_init, n_agents, lvalold, phi_i)
#      77
#      78     def eval_grad_f(x):
#
# /home/rccguest6110/OSE2019_JS/day1/SparseGridCode/growth_model/adaptive_stochastic/ipopt_wrapper.py in EV_F_ITER(X, k_init, n_agents, lvalold, phi_i)
#      58         pi*lvalold[2].evaluate(knext) +
#      59         pi*lvalold[3].evaluate(knext) +
# ---> 60         pi*lvalold[4].evaluate(knext))
#      61
#      62     return VT_sum
#
# /home/rccguest6110/OSE2019_JS/day1/SparseGridCode/growth_model/adaptive_stochastic/TasmanianSG.pyc in evaluate(self, lfX)
#     878         iNumX = len(lfX)
#     879         if (iNumX != self.getNumDimensions()):
# --> 880             raise TasmanianInputError("lfX", "ERROR: lfX should have lenth {0:1d} instead it has length {1:1d}".format(iNumX, self.getNumDimensions()))
#     881         pX = (c_double*iNumX)()
#     882         for iI in range(iNumX):
#
# TasmanianInputError:
# ERROR: found problem with lfX
# ERROR: lfX should have lenth 2 instead it has length 0
# succes 3
# succes 1
# succes 2
# [<TasmanianSG.TasmanianSparseGrid instance at 0x7f594dc51830>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f594dbb77a0>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f594db6f9e0>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f594db1ef80>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f5955b03a70>]
# ('lvalold0', <TasmanianSG.TasmanianSparseGrid instance at 0x7f594dc51830>)
# [5009.79794716 4994.15102739]
# ---------------------------------------------------------------------------
# TasmanianInputError                       Traceback (most recent call last)
# /home/rccguest6110/OSE2019_JS/day1/SparseGridCode/growth_model/adaptive_stochastic/nonlinear_solver_iterate.pyc in eval_f(X)
#      74
#      75     def eval_f(X):
# ---> 76         return EV_F_ITER(X, k_init, n_agents, lvalold, phi_i)
#      77
#      78     def eval_grad_f(x):
#
# /home/rccguest6110/OSE2019_JS/day1/SparseGridCode/growth_model/adaptive_stochastic/ipopt_wrapper.py in EV_F_ITER(X, k_init, n_agents, lvalold, phi_i)
#      58         pi*lvalold[2].evaluate(knext) +
#      59         pi*lvalold[3].evaluate(knext) +
# ---> 60         pi*lvalold[4].evaluate(knext))
#      61
#      62     return VT_sum
#
# /home/rccguest6110/OSE2019_JS/day1/SparseGridCode/growth_model/adaptive_stochastic/TasmanianSG.pyc in evaluate(self, lfX)
#     878         iNumX = len(lfX)
#     879         if (iNumX != self.getNumDimensions()):
# --> 880             raise TasmanianInputError("lfX", "ERROR: lfX should have lenth {0:1d} instead it has length {1:1d}".format(iNumX, self.getNumDimensions()))
#     881         pX = (c_double*iNumX)()
#     882         for iI in range(iNumX):
#
# TasmanianInputError:
# ERROR: found problem with lfX
# ERROR: lfX should have lenth 2 instead it has length 0
# succes 3
# succes 1
# succes 2
# [<TasmanianSG.TasmanianSparseGrid instance at 0x7f594dc51830>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f594dbb77a0>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f594db6f9e0>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f594db1ef80>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f5955b03a70>]
# ('lvalold0', <TasmanianSG.TasmanianSparseGrid instance at 0x7f594dc51830>)
# [5009.79794716 4996.88102739]
# ---------------------------------------------------------------------------
# TasmanianInputError                       Traceback (most recent call last)
# /home/rccguest6110/OSE2019_JS/day1/SparseGridCode/growth_model/adaptive_stochastic/nonlinear_solver_iterate.pyc in eval_f(X)
#      74
#      75     def eval_f(X):
# ---> 76         return EV_F_ITER(X, k_init, n_agents, lvalold, phi_i)
#      77
#      78     def eval_grad_f(x):
#
# /home/rccguest6110/OSE2019_JS/day1/SparseGridCode/growth_model/adaptive_stochastic/ipopt_wrapper.py in EV_F_ITER(X, k_init, n_agents, lvalold, phi_i)
#      58         pi*lvalold[2].evaluate(knext) +
#      59         pi*lvalold[3].evaluate(knext) +
# ---> 60         pi*lvalold[4].evaluate(knext))
#      61
#      62     return VT_sum
#
# /home/rccguest6110/OSE2019_JS/day1/SparseGridCode/growth_model/adaptive_stochastic/TasmanianSG.pyc in evaluate(self, lfX)
#     878         iNumX = len(lfX)
#     879         if (iNumX != self.getNumDimensions()):
# --> 880             raise TasmanianInputError("lfX", "ERROR: lfX should have lenth {0:1d} instead it has length {1:1d}".format(iNumX, self.getNumDimensions()))
#     881         pX = (c_double*iNumX)()
#     882         for iI in range(iNumX):
#
# TasmanianInputError:
# ERROR: found problem with lfX
# ERROR: lfX should have lenth 2 instead it has length 0
# succes 3
# succes 1
# succes 2
# [<TasmanianSG.TasmanianSparseGrid instance at 0x7f594dc51830>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f594dbb77a0>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f594db6f9e0>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f594db1ef80>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f5955b03a70>]
# ('lvalold0', <TasmanianSG.TasmanianSparseGrid instance at 0x7f594dc51830>)
# [5008.43294716 4995.51602739]
# ---------------------------------------------------------------------------
# TasmanianInputError                       Traceback (most recent call last)
# /home/rccguest6110/OSE2019_JS/day1/SparseGridCode/growth_model/adaptive_stochastic/nonlinear_solver_iterate.pyc in eval_f(X)
#      74
#      75     def eval_f(X):
# ---> 76         return EV_F_ITER(X, k_init, n_agents, lvalold, phi_i)
#      77
#      78     def eval_grad_f(x):
#
# /home/rccguest6110/OSE2019_JS/day1/SparseGridCode/growth_model/adaptive_stochastic/ipopt_wrapper.py in EV_F_ITER(X, k_init, n_agents, lvalold, phi_i)
#      58         pi*lvalold[2].evaluate(knext) +
#      59         pi*lvalold[3].evaluate(knext) +
# ---> 60         pi*lvalold[4].evaluate(knext))
#      61
#      62     return VT_sum
#
# /home/rccguest6110/OSE2019_JS/day1/SparseGridCode/growth_model/adaptive_stochastic/TasmanianSG.pyc in evaluate(self, lfX)
#     878         iNumX = len(lfX)
#     879         if (iNumX != self.getNumDimensions()):
# --> 880             raise TasmanianInputError("lfX", "ERROR: lfX should have lenth {0:1d} instead it has length {1:1d}".format(iNumX, self.getNumDimensions()))
#     881         pX = (c_double*iNumX)()
#     882         for iI in range(iNumX):
#
# TasmanianInputError:
# ERROR: found problem with lfX
# ERROR: lfX should have lenth 2 instead it has length 0
# succes 3
# succes 1
# succes 2
# ...
# TypeError                                 Traceback (most recent call last)
# /home/rccguest6110/OSE2019_JS/day1/SparseGridCode/growth_model/adaptive_stochastic/nonlinear_solver_iterate.pyc in eval_g(x)
#      80
#      81     def eval_g(x):
# ---> 82         return EV_G_ITER(X, k_init, n_agents)
#      83
#      84     def eval_jac_g(x, flag):
#
# TypeError: EV_G_ITER() takes exactly 4 arguments (3 given)
# succes 3
# succes 1
# succes 2
# [<TasmanianSG.TasmanianSparseGrid instance at 0x7f594da84050>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f594db505a8>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f594da92170>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f594da961b8>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f594da8d8c0>]
# ('lvalold0', <TasmanianSG.TasmanianSparseGrid instance at 0x7f594da84050>)
# [5011.16294716 4995.51602739]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/rccguest6110/OSE2019_JS/day1/SparseGridCode/growth_model/adaptive_stochastic/nonlinear_solver_iterate.pyc in eval_g(x)
#      80
#      81     def eval_g(x):
# ---> 82         return EV_G_ITER(X, k_init, n_agents)
#      83
#      84     def eval_jac_g(x, flag):
#
# TypeError: EV_G_ITER() takes exactly 4 arguments (3 given)
# succes 3
# 5
# ('Refinement level', 0)
# 0
# ('Refinement level', 1)
# 0
# ('Refinement level', 2)
# ('Evaluating grid for state', 2)
# reaching T's error
# 5
# succes 1
# succes 2
# [<TasmanianSG.TasmanianSparseGrid instance at 0x7f594da84050>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f594da7b5f0>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f594da92170>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f594da961b8>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f594da8d8c0>]
# ('lvalold0', <TasmanianSG.TasmanianSparseGrid instance at 0x7f594da84050>)
# [5009.79794716 4995.51602739]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/rccguest6110/OSE2019_JS/day1/SparseGridCode/growth_model/adaptive_stochastic/nonlinear_solver_iterate.pyc in eval_g(x)
#      80
#      81     def eval_g(x):
# ---> 82         return EV_G_ITER(X, k_init, n_agents)
#      83
#      84     def eval_jac_g(x, flag):
#
# TypeError: EV_G_ITER() takes exactly 4 arguments (3 given)
# succes 3
# succes 1
# succes 2
# [<TasmanianSG.TasmanianSparseGrid instance at 0x7f594da84050>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f594da7b5f0>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f594da92170>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f594da961b8>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f594da8d8c0>]
# ('lvalold0', <TasmanianSG.TasmanianSparseGrid instance at 0x7f594da84050>)
# [5009.79794716 4994.15102739]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/rccguest6110/OSE2019_JS/day1/SparseGridCode/growth_model/adaptive_stochastic/nonlinear_solver_iterate.pyc in eval_g(x)
#      80
#      81     def eval_g(x):
# ---> 82         return EV_G_ITER(X, k_init, n_agents)
#      83
#      84     def eval_jac_g(x, flag):
#
# TypeError: EV_G_ITER() takes exactly 4 arguments (3 given)
# succes 3
# succes 1
# succes 2
# [<TasmanianSG.TasmanianSparseGrid instance at 0x7f594da84050>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f594da7b5f0>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f594da92170>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f594da961b8>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f594da8d8c0>]
# ('lvalold0', <TasmanianSG.TasmanianSparseGrid instance at 0x7f594da84050>)
# [5009.79794716 4996.88102739]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/rccguest6110/OSE2019_JS/day1/SparseGridCode/growth_model/adaptive_stochastic/nonlinear_solver_iterate.pyc in eval_g(x)
#      80
#      81     def eval_g(x):
# ---> 82         return EV_G_ITER(X, k_init, n_agents)
#      83
#      84     def eval_jac_g(x, flag):
#
# TypeError: EV_G_ITER() takes exactly 4 arguments (3 given)
# succes 3
# succes 1
# succes 2
# [<TasmanianSG.TasmanianSparseGrid instance at 0x7f594da84050>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f594da7b5f0>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f594da92170>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f594da961b8>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f594da8d8c0>]
# ('lvalold0', <TasmanianSG.TasmanianSparseGrid instance at 0x7f594da84050>)
# [5008.43294716 4995.51602739]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/rccguest6110/OSE2019_JS/day1/SparseGridCode/growth_model/adaptive_stochastic/nonlinear_solver_iterate.pyc in eval_g(x)
#      80
#      81     def eval_g(x):
# ---> 82         return EV_G_ITER(X, k_init, n_agents)
#      83
#      84     def eval_jac_g(x, flag):
#
# TypeError: EV_G_ITER() takes exactly 4 arguments (3 given)
# succes 3
# succes 1
# succes 2
# [<TasmanianSG.TasmanianSparseGrid instance at 0x7f594da84050>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f594da7b5f0>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f594da92170>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f594da961b8>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f594da8d8c0>]
# ('lvalold0', <TasmanianSG.TasmanianSparseGrid instance at 0x7f594da84050>)
# [5011.16294716 4995.51602739]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/rccguest6110/OSE2019_JS/day1/SparseGridCode/growth_model/adaptive_stochastic/nonlinear_solver_iterate.pyc in eval_g(x)
#      80
#      81     def eval_g(x):
# ---> 82         return EV_G_ITER(X, k_init, n_agents)
#      83
#      84     def eval_jac_g(x, flag):
#
# TypeError: EV_G_ITER() takes exactly 4 arguments (3 given)
# succes 3
# 5
# ('Refinement level', 0)
# 0
# ('Refinement level', 1)
# 0
# ('Refinement level', 2)
# ('Evaluating grid for state', 3)
# reaching T's error
# 5
# succes 1
# succes 2
# [<TasmanianSG.TasmanianSparseGrid instance at 0x7f594da84050>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f594da7b5f0>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f594dafa7a0>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f594da961b8>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f594da8d8c0>]
# ('lvalold0', <TasmanianSG.TasmanianSparseGrid instance at 0x7f594da84050>)
# [5009.79794716 4995.51602739]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/rccguest6110/OSE2019_JS/day1/SparseGridCode/growth_model/adaptive_stochastic/nonlinear_solver_iterate.pyc in eval_g(x)
#      80
#      81     def eval_g(x):
# ---> 82         return EV_G_ITER(X, k_init, n_agents)
#      83
#      84     def eval_jac_g(x, flag):
#
# TypeError: EV_G_ITER() takes exactly 4 arguments (3 given)
# succes 3
# succes 1
# succes 2
# [<TasmanianSG.TasmanianSparseGrid instance at 0x7f594da84050>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f594da7b5f0>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f594dafa7a0>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f594da961b8>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f594da8d8c0>]
# ('lvalold0', <TasmanianSG.TasmanianSparseGrid instance at 0x7f594da84050>)
# [5009.79794716 4994.15102739]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/rccguest6110/OSE2019_JS/day1/SparseGridCode/growth_model/adaptive_stochastic/nonlinear_solver_iterate.pyc in eval_g(x)
#      80
#      81     def eval_g(x):
# ---> 82         return EV_G_ITER(X, k_init, n_agents)
#      83
#      84     def eval_jac_g(x, flag):
#
# TypeError: EV_G_ITER() takes exactly 4 arguments (3 given)
# succes 3
# succes 1
# succes 2
# [<TasmanianSG.TasmanianSparseGrid instance at 0x7f594da84050>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f594da7b5f0>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f594dafa7a0>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f594da961b8>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f594da8d8c0>]
# ('lvalold0', <TasmanianSG.TasmanianSparseGrid instance at 0x7f594da84050>)
# [5009.79794716 4996.88102739]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/rccguest6110/OSE2019_JS/day1/SparseGridCode/growth_model/adaptive_stochastic/nonlinear_solver_iterate.pyc in eval_g(x)
#      80
#      81     def eval_g(x):
# ---> 82         return EV_G_ITER(X, k_init, n_agents)
#      83
#      84     def eval_jac_g(x, flag):
#
# TypeError: EV_G_ITER() takes exactly 4 arguments (3 given)
# succes 3
# succes 1
# succes 2
# [<TasmanianSG.TasmanianSparseGrid instance at 0x7f594da84050>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f594da7b5f0>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f594dafa7a0>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f594da961b8>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f594da8d8c0>]
# ('lvalold0', <TasmanianSG.TasmanianSparseGrid instance at 0x7f594da84050>)
# [5008.43294716 4995.51602739]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/rccguest6110/OSE2019_JS/day1/SparseGridCode/growth_model/adaptive_stochastic/nonlinear_solver_iterate.pyc in eval_g(x)
#      80
#      81     def eval_g(x):
# ---> 82         return EV_G_ITER(X, k_init, n_agents)
#      83
#      84     def eval_jac_g(x, flag):
#
# TypeError: EV_G_ITER() takes exactly 4 arguments (3 given)
# succes 3
# succes 1
# succes 2
# [<TasmanianSG.TasmanianSparseGrid instance at 0x7f594da84050>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f594da7b5f0>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f594dafa7a0>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f594da961b8>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f594da8d8c0>]
# ('lvalold0', <TasmanianSG.TasmanianSparseGrid instance at 0x7f594da84050>)
# [5011.16294716 4995.51602739]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/rccguest6110/OSE2019_JS/day1/SparseGridCode/growth_model/adaptive_stochastic/nonlinear_solver_iterate.pyc in eval_g(x)
#      80
#      81     def eval_g(x):
# ---> 82         return EV_G_ITER(X, k_init, n_agents)
#      83
#      84     def eval_jac_g(x, flag):
#
# TypeError: EV_G_ITER() takes exactly 4 arguments (3 given)
# succes 3
# 5
# ('Refinement level', 0)
# 0
# ('Refinement level', 1)
# 0
# ('Refinement level', 2)
# ('Evaluating grid for state', 4)
# reaching T's error
# 5
# succes 1
# succes 2
# [<TasmanianSG.TasmanianSparseGrid instance at 0x7f594da84050>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f594da7b5f0>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f594dafa7a0>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f594df76560>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f594da8d8c0>]
# ('lvalold0', <TasmanianSG.TasmanianSparseGrid instance at 0x7f594da84050>)
# [5009.79794716 4995.51602739]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/rccguest6110/OSE2019_JS/day1/SparseGridCode/growth_model/adaptive_stochastic/nonlinear_solver_iterate.pyc in eval_g(x)
#      80
#      81     def eval_g(x):
# ---> 82         return EV_G_ITER(X, k_init, n_agents)
#      83
#      84     def eval_jac_g(x, flag):
#
# TypeError: EV_G_ITER() takes exactly 4 arguments (3 given)
# succes 3
# succes 1
# succes 2
# [<TasmanianSG.TasmanianSparseGrid instance at 0x7f594da84050>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f594da7b5f0>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f594dafa7a0>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f594df76560>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f594da8d8c0>]
# ('lvalold0', <TasmanianSG.TasmanianSparseGrid instance at 0x7f594da84050>)
# [5009.79794716 4994.15102739]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/rccguest6110/OSE2019_JS/day1/SparseGridCode/growth_model/adaptive_stochastic/nonlinear_solver_iterate.pyc in eval_g(x)
#      80
#      81     def eval_g(x):
# ---> 82         return EV_G_ITER(X, k_init, n_agents)
#      83
#      84     def eval_jac_g(x, flag):
#
# TypeError: EV_G_ITER() takes exactly 4 arguments (3 given)
# succes 3
# succes 1
# succes 2
# [<TasmanianSG.TasmanianSparseGrid instance at 0x7f594da84050>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f594da7b5f0>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f594dafa7a0>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f594df76560>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f594da8d8c0>]
# ('lvalold0', <TasmanianSG.TasmanianSparseGrid instance at 0x7f594da84050>)
# [5009.79794716 4996.88102739]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/rccguest6110/OSE2019_JS/day1/SparseGridCode/growth_model/adaptive_stochastic/nonlinear_solver_iterate.pyc in eval_g(x)
#      80
#      81     def eval_g(x):
# ---> 82         return EV_G_ITER(X, k_init, n_agents)
#      83
#      84     def eval_jac_g(x, flag):
#
# TypeError: EV_G_ITER() takes exactly 4 arguments (3 given)
# succes 3
# succes 1
# succes 2
# [<TasmanianSG.TasmanianSparseGrid instance at 0x7f594da84050>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f594da7b5f0>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f594dafa7a0>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f594df76560>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f594da8d8c0>]
# ('lvalold0', <TasmanianSG.TasmanianSparseGrid instance at 0x7f594da84050>)
# [5008.43294716 4995.51602739]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/rccguest6110/OSE2019_JS/day1/SparseGridCode/growth_model/adaptive_stochastic/nonlinear_solver_iterate.pyc in eval_g(x)
#      80
#      81     def eval_g(x):
# ---> 82         return EV_G_ITER(X, k_init, n_agents)
#      83
#      84     def eval_jac_g(x, flag):
#
# TypeError: EV_G_ITER() takes exactly 4 arguments (3 given)
# succes 3
# succes 1
# succes 2
# [<TasmanianSG.TasmanianSparseGrid instance at 0x7f594da84050>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f594da7b5f0>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f594dafa7a0>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f594df76560>, <TasmanianSG.TasmanianSparseGrid instance at 0x7f594da8d8c0>]
# ('lvalold0', <TasmanianSG.TasmanianSparseGrid instance at 0x7f594da84050>)
# [5011.16294716 4995.51602739]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/rccguest6110/OSE2019_JS/day1/SparseGridCode/growth_model/adaptive_stochastic/nonlinear_solver_iterate.pyc in eval_g(x)
#      80
#      81     def eval_g(x):
# ---> 82         return EV_G_ITER(X, k_init, n_agents)
#      83
#      84     def eval_jac_g(x, flag):
#
# TypeError: EV_G_ITER() takes exactly 4 arguments (3 given)
# succes 3
# 5
# ('Refinement level', 0)
# 0
# ('Refinement level', 1)
# 0
# ('Refinement level', 2)
# ===============================================================
#
# (' Computation of a growth model of dimension ', 2, ' finished after ', 10, ' steps')
#
# ===============================================================
# ===============================================================
#
#  Errors are computed -- see errors.txt
#
# ===============================================================

# %%
"""
The obtained values (objective) should be very close to beta :
the contraction mapping
"""
# Out:
# '\nThe obtained values (objective) should be very close to beta :\nthe contraction mapping\n'

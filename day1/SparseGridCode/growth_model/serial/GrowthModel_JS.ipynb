# %%
#======================================================================
#
#     This routine solves an infinite horizon growth model 
#     with dynamic programming and sparse grids
#
#     The model is described in Scheidegger & Bilionis (2017)
#     https://papers.ssrn.com/sol3/papers.cfm?abstract_id=2927400
#
#     external libraries needed:
#     - IPOPT (https://projects.coin-or.org/Ipopt)
#     - PYIPOPT (https://github.com/xuy/pyipopt)
#     - TASMANIAN (http://tasmanian.ornl.gov/)
#
#     Simon Scheidegger, 11/16 ; 07/17
#======================================================================

import nonlinear_solver_initial as solver     #solves opt. problems for terminal VF
import nonlinear_solver_iterate as solviter   #solves opt. problems during VFI
from parameters import *                      #parameters of model
import interpolation as interpol              #interface to sparse grid library/terminal VF
import interpolation_iter as interpol_iter    #interface to sparse grid library/iteration
import postprocessing as post                 #computes the L2 and Linfinity error of the model

import TasmanianSG                            #sparse grid library
import numpy as np


#======================================================================
# Start with Value Function Iteration

# terminal value function : "ss", no uncertainty --> ss values of c,l,k
valnew=TasmanianSG.TasmanianSparseGrid()
if (numstart==0):
    valnew=interpol.sparse_grid(n_agents, iDepth)
    points = valnew.getPoints()
    #print(points)
    testkm = valnew.evaluateBatch(points)
    testkm2 = testkm
    valnew.write("valnew_1." + str(numstart) + ".txt") #write file to disk for restart
    
# value function during iteration --> take ss values of c,l,k and 
else:
    valnew.read("valnew_1." + str(numstart) + ".txt")  #write file to disk for restart
    
valold=TasmanianSG.TasmanianSparseGrid()
valold=valnew

for i in range(numstart, numits):
    print(i)
    valnew=TasmanianSG.TasmanianSparseGrid()
    valnew=interpol_iter.sparse_grid_iter(n_agents, iDepth, valold)
    valold=TasmanianSG.TasmanianSparseGrid()
    points = valnew.getPoints()
    valold=valnew
    valnew.write("valnew_1." + str(i+1) + ".txt")
    testk = valnew.evaluateBatch(points)
    #print((testk - testkm)/(testkm - testkm2))
    testkm2 = testkm
    testkm = testk

#======================================================================
print( "===============================================================")
print( " " )
print( " Computation of a growth model of dimension ", n_agents ," finished after ", numits, " steps")
print( " " )
print( "===============================================================")
#======================================================================

# compute errors   
avg_err=post.ls_error(n_agents, numstart, numits, No_samples)

#======================================================================
print( "===============================================================")
print( " ")
print( " Errors are computed -- see errors.txt")
print( " ")
print( "===============================================================")
#======================================================================
# Out:
# ('Number of points in grid is', 7)
# ('Solving for point', 0)
# ('The value of the objective function is', 2.3729767508820845)
# ('Solving for point', 1)
# ('The value of the objective function is', -0.6465300684965978)
# ('Solving for point', 2)
# ('The value of the objective function is', 3.294773313558534)
# ('Solving for point', 3)
# ('The value of the objective function is', -0.646530068399765)
# ('Solving for point', 4)
# ('The value of the objective function is', 3.2947733135617563)
# ('Solving for point', 5)
# ('The value of the objective function is', -0.6465300683787236)
# ('Solving for point', 6)
# ('The value of the objective function is', 3.294773313579249)
# 0
# ('Number of points in grid is', 7)
# ('Solving for point', 0)
# ('The value of the objective function is', -203.59044925874727)
# ('Solving for point', 1)
# ('The value of the objective function is', -205.94566457684255)
# ('Solving for point', 2)
# ('The value of the objective function is', -202.83548717878722)
# ('Solving for point', 3)
# ('The value of the objective function is', -205.94566457781053)
# ('Solving for point', 4)
# ('The value of the objective function is', -202.83548718092774)
# ('Solving for point', 5)
# ('The value of the objective function is', -205.9456645777941)
# ('Solving for point', 6)
# ('The value of the objective function is', -202.83548718091475)
# 1
# ('Number of points in grid is', 7)
# ('Solving for point', 0)
# ('The value of the objective function is', -368.32702649217634)
# ('Solving for point', 1)
# ('The value of the objective function is', -370.16409443927057)
# ('Solving for point', 2)
# ('The value of the objective function is', -367.71072314843786)
# ('Solving for point', 3)
# ('The value of the objective function is', -370.1640944410691)
# ('Solving for point', 4)
# ('The value of the objective function is', -367.71072314691696)
# ('Solving for point', 5)
# ('The value of the objective function is', -370.1640944410563)
# ('Solving for point', 6)
# ('The value of the objective function is', -367.71072314778814)
# 2
# ('Number of points in grid is', 7)
# ('Solving for point', 0)
# ('The value of the objective function is', -500.08964069098556)
# ('Solving for point', 1)
# ('The value of the objective function is', -501.52255368869896)
# ('Solving for point', 2)
# ('The value of the objective function is', -499.5879966800422)
# ('Solving for point', 3)
# ('The value of the objective function is', -501.52255369164266)
# ('Solving for point', 4)
# ('The value of the objective function is', -499.58799668181587)
# ('Solving for point', 5)
# ('The value of the objective function is', -501.52255369163254)
# ('Solving for point', 6)
# ('The value of the objective function is', -499.5879966824807)
# 3
# ('Number of points in grid is', 7)
# ('Solving for point', 0)
# ('The value of the objective function is', -605.4789469314615)
# ('Solving for point', 1)
# ('The value of the objective function is', -606.5966190686579)
# ('Solving for point', 2)
# ('The value of the objective function is', -605.0716999837512)
# ('Solving for point', 3)
# ('The value of the objective function is', -606.5966190724947)
# ('Solving for point', 4)
# ('The value of the objective function is', -605.0716999880185)
# ('Solving for point', 5)
# ('The value of the objective function is', -606.5966190724869)
# ('Solving for point', 6)
# ('The value of the objective function is', -605.0716999885259)
# 4
# ('Number of points in grid is', 7)
# ('Solving for point', 0)
# ('The value of the objective function is', -689.7741795313564)
# ('Solving for point', 1)
# ('The value of the objective function is', -690.6459637973495)
# ('Solving for point', 2)
# ('The value of the objective function is', -689.4443481878975)
# ('Solving for point', 3)
# ('The value of the objective function is', -690.6459638018831)
# ('Solving for point', 4)
# ('The value of the objective function is', -689.4443481940519)
# ('Solving for point', 5)
# ('The value of the objective function is', -690.6459638018769)
# ('Solving for point', 6)
# ('The value of the objective function is', -689.444348194439)
# 5
# ('Number of points in grid is', 7)
# ('Solving for point', 0)
# ('The value of the objective function is', -757.1977199451335)
# ('Solving for point', 1)
# ('The value of the objective function is', -757.8777116715879)
# ('Solving for point', 2)
# ('The value of the objective function is', -756.9311608699584)
# ('Solving for point', 3)
# ('The value of the objective function is', -757.8777116766651)
# ('Solving for point', 4)
# ('The value of the objective function is', -756.9311608775404)
# ('Solving for point', 5)
# ('The value of the objective function is', -757.87771167666)
# ('Solving for point', 6)
# ('The value of the objective function is', -756.9311608778357)
# 6
# ('Number of points in grid is', 7)
# ('Solving for point', 0)
# ('The value of the objective function is', -811.1266886565668)
# ('Solving for point', 1)
# ('The value of the objective function is', -811.6570822021812)
# ('Solving for point', 2)
# ('The value of the objective function is', -810.9116851560375)
# ('Solving for point', 3)
# ('The value of the objective function is', -811.6570822076822)
# ('Solving for point', 4)
# ('The value of the objective function is', -810.9116851646992)
# ('Solving for point', 5)
# ('The value of the objective function is', -811.6570822076781)
# ('Solving for point', 6)
# ('The value of the objective function is', -810.9116851649245)
# 7
# ('Number of points in grid is', 7)
# ('Solving for point', 0)
# ('The value of the objective function is', -854.2621700024345)
# ('Solving for point', 1)
# ('The value of the objective function is', -854.6758769669938)
# ('Solving for point', 2)
# ('The value of the objective function is', -854.0890605810812)
# ('Solving for point', 3)
# ('The value of the objective function is', -854.6758769728252)
# ('Solving for point', 4)
# ('The value of the objective function is', -854.0890605905593)
# ('Solving for point', 5)
# ('The value of the objective function is', -854.6758769728219)
# ('Solving for point', 6)
# ('The value of the objective function is', -854.0890605907313)
# 8
# ('Number of points in grid is', 7)
# ('Solving for point', 0)
# ('The value of the objective function is', -888.7645540529711)
# ('Solving for point', 1)
# ('The value of the objective function is', -889.0872454843073)
# ('Solving for point', 2)
# ('The value of the objective function is', -888.6254041709774)
# ('Solving for point', 3)
# ('The value of the objective function is', -889.0872454903966)
# ('Solving for point', 4)
# ('The value of the objective function is', -888.6254041810727)
# ('Solving for point', 5)
# ('The value of the objective function is', -889.087245490394)
# ('Solving for point', 6)
# ('The value of the objective function is', -888.6254041812041)
# 9
# ('Number of points in grid is', 7)
# ('Solving for point', 0)
# ('The value of the objective function is', -916.3617804929975)
# ('Solving for point', 1)
# ('The value of the objective function is', -916.6134798084197)
# ('Solving for point', 2)
# ('The value of the objective function is', -916.2500971547822)
# ('Solving for point', 3)
# ('The value of the objective function is', -916.6134798147101)
# ('Solving for point', 4)
# ('The value of the objective function is', -916.2500971653438)
# ('Solving for point', 5)
# ('The value of the objective function is', -916.613479814708)
# ('Solving for point', 6)
# ('The value of the objective function is', -916.2500971654442)
# ===============================================================
#
# (' Computation of a growth model of dimension ', 3, ' finished after ', 10, ' steps')
#
# ===============================================================
# ===============================================================
#
#  Errors are computed -- see errors.txt
#
# ===============================================================
